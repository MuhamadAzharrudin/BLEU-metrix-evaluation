# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statistics import mean, median, stdev

# --- Load Data ---
df = pd.read_csv("hasil_parafrase.csv")

# --- Hitung Metrik BLEU ---
bleu_scores = df['bleu_score'].tolist()

avg_bleu = mean(bleu_scores)
median_bleu = median(bleu_scores)
std_bleu = stdev(bleu_scores)

print("📊 Evaluasi BLEU:")
print(f"🔹 Rata-rata BLEU: {avg_bleu:.4f}")
print(f"🔹 Median BLEU: {median_bleu:.4f}")
print(f"🔹 Standard Deviasi: {std_bleu:.4f}")
print(f"🔹 Skor BLEU Tertinggi: {max(bleu_scores):.4f}")
print(f"🔹 Skor BLEU Terendah: {min(bleu_scores):.4f}")

# --- Plot Distribusi BLEU ---
plt.figure(figsize=(10, 5))
sns.histplot(bleu_scores, bins=10, kde=True, color='skyblue')
plt.title("Distribusi Skor BLEU")
plt.xlabel("Skor BLEU")
plt.ylabel("Jumlah Sample")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# 📊 Evaluasi BLEU:
# 🔹 Rata-rata BLEU: 0.8439
# 🔹 Median BLEU: 1.0000
# 🔹 Standard Deviasi: 0.2477
# 🔹 Skor BLEU Tertinggi: 1.0000
# 🔹 Skor BLEU Terendah: 0.4315
